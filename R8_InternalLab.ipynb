# %% [markdown]
# # Sentiment analysis
#
# The objective of this problem is to perform Sentiment analysis from the tweets collected from the users targeted at various mobile devices.
# Based on the tweet posted by a user (text), we will classify if the sentiment of the user targeted at a particular mobile device is positive or not.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/ColabNotebooks/SNLP/LABINTERNAL/'

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Read the data
# - read tweets.csv
# - use latin encoding if it gives encoding error while loading

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
df= pd.read_csv(path + 'tweets.csv',encoding='latin')

# %%
#checking for null values
df.isnull().sum()
# Out:
# tweet_text                                               1
# emotion_in_tweet_is_directed_at                       5802
# is_there_an_emotion_directed_at_a_brand_or_product       0
# dtype: int64

# %% [markdown]
# ### Drop null values
# - drop all the rows with null values

# %%
df.dropna(subset=['tweet_text'],inplace=True)

# %% [markdown]
# ### Print the dataframe
# - print initial 5 rows of the data
# - use df.head()

# %%
df.head(5)
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...  ...                                   Negative emotion
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...  ...                                   Positive emotion
# 2  @swonderlin Can not wait for #iPad 2 also. The...  ...                                   Positive emotion
# 3  @sxsw I hope this year's festival isn't as cra...  ...                                   Negative emotion
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Preprocess data
# - convert all text to lowercase - use .lower()
# - select only numbers, alphabets, and #+_ from text - use re.sub()
# - strip all the text - use .strip()
#     - this is for removing extra spaces

# %%
df['tweet_text'] = df['tweet_text'].apply(lambda s: s.lower())
df['tweet_text'] = df['tweet_text'].apply(lambda s: re.sub('[^0-9a-z #+_]','',s))
df['tweet_text'] = df['tweet_text'].apply(lambda s: s.strip())

# %% [markdown]
# print dataframe

# %%
df.head()
# Out:
#                                           tweet_text  ... is_there_an_emotion_directed_at_a_brand_or_product
# 0  wesley83 i have a 3g iphone after 3 hrs tweeti...  ...                                   Negative emotion
# 1  jessedee know about fludapp  awesome ipadiphon...  ...                                   Positive emotion
# 2  swonderlin can not wait for #ipad 2 also they ...  ...                                   Positive emotion
# 3  sxsw i hope this years festival isnt as crashy...  ...                                   Negative emotion
# 4  sxtxstate great stuff on fri #sxsw marissa may...  ...                                   Positive emotion
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Preprocess data
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - select only those rows where value equal to "positive emotion" or "negative emotion"
# - find the value counts of "positive emotion" and "negative emotion"

# %%
df.is_there_an_emotion_directed_at_a_brand_or_product.unique()
# Out:
# array(['Negative emotion', 'Positive emotion',
#        'No emotion toward brand or product', "I can't tell"], dtype=object)

# %%
df= df[df.is_there_an_emotion_directed_at_a_brand_or_product.isin(['Negative emotion','Positive emotion'])]

# %%
df.is_there_an_emotion_directed_at_a_brand_or_product.value_counts()
# Out:
# Positive emotion    2978
# Negative emotion     570
# Name: is_there_an_emotion_directed_at_a_brand_or_product, dtype: int64

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Encode labels
# - in column "is_there_an_emotion_directed_at_a_brand_or_product"
#     - change "positive emotion" to 1
#     - change "negative emotion" to 0
# - use map function to replace values

# %%
df['is_there_an_emotion_directed_at_a_brand_or_product']=df['is_there_an_emotion_directed_at_a_brand_or_product'].map(lambda x: 1 if x=='Positive emotion' else 0)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Get feature and label
# - get column "tweet_text" as feature
# - get column "is_there_an_emotion_directed_at_a_brand_or_product" as label

# %%
X = df.tweet_text
y = df.is_there_an_emotion_directed_at_a_brand_or_product

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=.75,random_state=1)

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Vectorize data
# - create document-term matrix
# - use CountVectorizer()
#     - ngram_range: (1, 2)
#     - stop_words: 'english'
#     - min_df: 2
# - do fit_transform on X_train
# - do transform on X_test

# %%
# import and instantiate CountVectorizer (with the default parameters)
from sklearn.feature_extraction.text import CountVectorizer
cvect = CountVectorizer(ngram_range= (1, 2), stop_words= 'english', min_df = 2)

# %%
#Feed SMS data to CountVectorizer
X_train = cvect.fit_transform(X_train)
X_test = cvect.transform(X_test)

# %%
#Check the vocablury size
len(cvect.vocabulary_)
# Out:
# 6132

# %%
#What is there in the vocabulary
cvect.vocabulary_
# Out:
# {'rt': 4465,
#  'mention': 3324,
#  'google': 1954,
#  'talking': 5327,
#  'search': 4561,
#  'ranking': 4313,
#  'im': 2404,
#  'sure': 5026,
#  'saw': 4523,
#  'bing': 694,
#  'writing': 6053,
#  'notes': 3747,
#  'qagb': 4204,
#  'sxsw': 5054,
#  'rt mention': 4467,
#  'mention google': 3388,
#  'im sure': 2418,
#  'writing notes': 6054,
#  'qagb sxsw': 4205,
#  'look': 3119,
#  'blue': 729,
#  'hair': 2170,
#  'ive': 2754,
#  'got': 2059,
#  'free': 1785,
#  'android': 284,
#  'phone': 3960,
#  'info': 2464,
#  'stickers': 4902,
#  'allhat3': 235,
#  'mention sxsw': 3485,
#  'sxsw look': 5159,
#  'look blue': 3120,
#  'blue hair': 730,
#  'hair ive': 2171,
#  'ive got': 2756,
#  'got free': 2062,
#  'free android': 1786,
#  'android phone': 301,
#  'phone info': 3963,
#  'info stickers': 2471,
#  'stickers mention': 4903,
#  'mention allhat3': 3333,
#  'getting': 1894,
#  'new': 3686,
#  'ipad': 2533,
#  'flash': 1728,
#  'apple': 364,
#  'store': 4911,
#  'link': 3032,
#  'mention getting': 3383,
#  'new ipad': 3697,
#  'ipad sxsw': 2630,
#  'flash apple': 1729,
#  'apple store': 418,
#  'store link': 4936,
#  'winner': 5952,
#  'awesome': 565,
#  'mention awesome': 3341,
#  'got ipad': 2064,
#  'sxsw link': 5158,
#  'link mention': 3059,
#  'mention mention': 3444,
#  'panel': 3860,
#  'touch': 5564,
#  'interfaces': 2519,
#  'shows': 4687,
#  'bunch': 805,
#  'tablets': 5305,
#  'brilliant': 778,
#  'set': 4626,
#  'open': 3801,
#  'popup': 4073,
#  'shop': 4659,
#  'core': 1135,
#  'action': 163,
#  'theyre': 5440,
#  'going': 1923,
#  'sell': 4588,
#  'ipad2': 2643,
#  'mention apple': 3337,
#  'apple set': 412,
#  'set open': 4629,
#  'open popup': 3805,
#  'popup shop': 4079,
#  'shop core': 4661,
#  'core sxsw': 1136,
#  'sxsw action': 5059,
#  'action theyre': 168,
#  'theyre going': 5443,
#  'going sell': 1926,
#  'sell ipad2': 4592,
#  'ipad2 sxsw': 2657,
#  'great': 2091,
#  'pacman': 3855,
#  'doodles': 1409,
#  'session': 4620,
#  'details': 1309,
#  'google doodles': 1976,
#  'session mention': 4622,
#  'sxsw details': 5100,
#  'details link': 1311,
#  'coming': 1040,
#  'guess': 2136,
#  'apples': 432,
#  'pretty': 4120,
#  'attention': 502,
#  'ipad coming': 2553,
#  'coming sxsw': 1044,
#  'love': 3154,
#  'quotapple': 4237,
#  'comes': 1037,
#  'cool': 1119,
#  'technology': 5370,
#  'ones': 3797,
#  'heard': 2242,
#  'dont': 1401,
#  'conferencesquot': 1079,
#  'mention rt': 3468,
#  'mention love': 3441,
#  'love mention': 3158,
#  'sxsw quotapple': 5199,
#  'quotapple comes': 4238,
#  'comes cool': 1038,
#  'cool technology': 1129,
#  'technology ones': 5375,
#  'ones heard': 3798,
#  'heard dont': 2245,
#  'dont conferencesquot': 1402,
#  'real': 4333,
#  'time': 5498,
#  'location': 3098,
#  'data': 1210,
#  'earth': 1474,
#  'gives': 1905,
#  'visual': 5809,
#  'real time': 4334,
#  'location data': 3100,
#  'google earth': 1977,
#  'data sxsw': 1211,
#  'wish': 5977,
#  'said': 4492,
#  'wish sxsw': 5982,
#  'sxsw wish': 5264,
#  'wish ipad': 5979,
#  'ipad said': 2618,
#  'wait': 5823,
#  'anymore': 316,
#  'quotgoogle': 4255,
#  'launch': 2921,
#  'major': 3209,
#  'social': 4764,
#  'network': 3677,
#  'called': 853,
#  'circlesquot': 983,
#  'circles': 974,
#  'mention wait': 3504,
#  'wait anymore': 5824,
#  'anymore quotgoogle': 317,
#  'quotgoogle launch': 4257,
#  'launch major': 2929,
#  'major new': 3210,
#  'new social': 3709,
#  'social network': 4766,
#  'network called': 3678,
#  'called circlesquot': 855,
#  'circlesquot mention': 984,
#  'mention link': 3434,
#  'link google': 3045,
#  'google circles': 1967,
#  'circles sxsw': 981,
#  'hours': 2352,
#  'announce': 310,
#  'giveaway': 1902,
#  'sxswi': 5278,
#  'mention hours': 3412,
#  'hours announce': 2353,
#  'announce details': 311,
#  'details ipad': 1310,
#  'ipad giveaway': 2568,
#  'giveaway sxsw': 1904,
#  'sxsw sxswi': 5229,
#  'sold': 4782,
#  '70': 123,
#  'went': 5909,
#  'buyers': 827,
#  'report': 4387,
#  'socialmedia': 4775,
#  'ipad sold': 2624,
#  'sold 70': 4784,
#  '70 went': 126,
#  'went new': 5910,
#  'new buyers': 3690,
#  'buyers report': 828,
#  'report link': 4388,
#  'link sxsw': 3067,
#  'link socialmedia': 3066,
#  'connect': 1093,
#  'digital': 1340,
#  'amp': 254,
#  'physical': 3977,
#  'worlds': 6033,
#  'mobile': 3564,
#  'sxsw google': 5127,
#  'google connect': 1968,
#  'connect digital': 1094,
#  'digital amp': 1341,
#  'amp physical': 272,
#  'physical worlds': 3979,
#  'worlds mobile': 6035,
#  'mobile link': 3569,
#  'link link': 3053,
#  'woah': 5985,
#  'expect': 1589,
#  'today': 5528,
#  'googles': 2047,
#  'league': 2952,
#  'extraordinary': 1615,
#  'hackers': 2165,
#  'events': 1557,
#  'big': 679,
#  'woah expect': 5986,
#  'expect google': 1590,
#  'circles today': 982,
#  'today sxsw': 5536,
#  'sxsw googles': 5129,
#  'googles league': 2049,
#  'league extraordinary': 2953,
#  'extraordinary hackers': 1616,
#  'hackers events': 2166,
#  'events today': 1560,
#  'today big': 5530,
#  'iphone': 2676,
#  'natural': 3652,
#  'sxswnui': 5289,
#  'iphone ipad': 2707,
#  'wow': 6042,
#  'suck': 5002,
#  'black': 711,
#  'fab5': 1619,
#  'link ipad': 3048,
#  'month': 3599,
#  'discovr': 1360,
#  'midem': 3529,
#  'climbing': 1004,
#  'app': 319,
#  'charts': 930,
#  'month discovr': 3600,
#  'discovr ipad': 1362,
#  'ipad midem': 2594,
#  'midem time': 3530,
#  'time discovr': 5502,
#  'discovr iphone': 1363,
#  'iphone sxsw': 2721,
#  'sxsw climbing': 5086,
#  'climbing app': 1005,
#  'app store': 350,
#  'store charts': 4918,
#  'charts link': 931,
#  'bc': 634,
#  'shit': 4656,
#  'play': 4024,
#  'turn': 5629,
#  'guy': 2145,
#  'using': 5749,
#  'using ipad': 5752,
#  'nice': 3727,
#  'heading': 2232,
#  'barton': 613,
#  'pro': 4140,
#  'waiting': 5832,
#  'outside': 3841,
#  'woohoo': 6004,
#  'im heading': 2410,
#  'waiting outside': 5834,
#  'outside sxsw': 3843,
#  'sxsw apple': 5065,
#  'store ipad2': 4929,
#  'ipad2 woohoo': 2659,
#  'companies': 1055,
#  'like': 2985,
#  'facebook': 1622,
#  'monopoly': 3598,
#  'terms': 5401,
#  'service': 4617,
#  'like google': 2991,
#  'thoughts': 5477,
#  'agents': 205,
#  'sxsw popup': 5191,
#  'party': 3881,
#  'gsdampm': 2123,
#  'map': 3232,
#  'badge': 588,
#  'gets': 1890,
#  'food': 1755,
#  'drinks': 1441,
#  'music': 3638,
#  'place': 4004,
#  'line': 3012,
#  'come': 1024,
#  'google party': 2003,
#  'party gsdampm': 3890,
#  'gsdampm google': 2124,
#  'google map': 1999,
#  'map sxsw': 3233,
#  'sxsw badge': 5071,
#  'badge gets': 589,
#  'gets free': 1892,
#  'free food': 1791,
#  'food drinks': 1759,
#  'drinks music': 1442,
#  'music big': 3640,
#  'big place': 685,
#  'place line': 4006,
#  'line great': 3018,
#  'great party': 2101,
#  'party come': 3885,
#  'sampler': 4501,
#  'itunes': 2749,
#  'includes': 2452,
#  'opens': 3819,
#  'free sxsw': 1802,
#  'sxsw music': 5173,
#  'music sampler': 3644,
#  'sampler itunes': 4502,
#  'itunes link': 2753,
#  'oh': 3785,
#  'thats': 5426,
#  'just': 2803,
#  'thought': 5475,
#  'winning': 5953,
#  'oh thats': 3787,
#  'just ipad': 2815,
#  'mention saw': 3472,
#  'music app': 3639,
#  'future': 1838,
#  'quotthe': 4292,
#  'power': 4097,
#  'herequot': 2269,
#  'augmented': 508,
#  'reality': 4337,
#  'contextual': 1108,
#  'pnid': 4049,
#  'quotthe power': 4294,
#  'power herequot': 4098,
#  'augmented reality': 509,
#  'pnid sxsw': 4050,
#  'hootsuite': 2324,
#  'chilltab': 959,
#  'tablet': 5301,
#  'stand': 4865,
#  'rocks': 4450,
#  'canadian': 864,
#  'media': 3309,
#  'best': 656,
#  'sxsw hootsuite': 5138,
#  'hootsuite chilltab': 2325,
#  'chilltab tablet': 960,
#  'tablet stand': 5303,
#  'stand rocks': 4867,
#  'rocks canadian': 4451,
#  'canadian social': 865,
#  'social media': 4765,
#  'media ipad': 3310,
#  'ipad best': 2548,
#  'best mention': 662,
#  'amazing': 240,
#  'person': 3950,
#  'finder': 1718,
#  'mention social': 3479,
#  'google set': 2018,
#  'hey': 2273,
#  'mark': 3266,
#  'sleep': 4718,
#  'bring': 781,
#  'home': 2317,
#  'shiny': 4649,
#  'ya': 6066,
#  'mention hey': 3407,
#  'sleep sxsw': 4719,
#  'sxsw bring': 5077,
#  'shiny new': 4650,
#  'setting': 4634,
#  'austin': 511,
#  'bajillions': 592,
#  'ipad2s': 2660,
#  'attendees': 495,
#  'apple setting': 414,
#  'setting popup': 4636,
#  'popup store': 4080,
#  'store austin': 4916,
#  'austin sell': 531,
#  'sell bajillions': 4589,
#  'bajillions ipad2s': 593,
#  'ipad2s sxsw': 2661,
#  'sxsw attendees': 5068,
#  'link brilliant': 3036,
#  'news': 3717,
#  'audience': 506,
#  'heads': 2237,
#  'door': 1412,
#  'app ipad': 332,
#  'door sxsw': 1413,
#  'mention big': 3345,
#  'big news': 684,
#  'news link': 3721,
#  'want': 5844,
#  'make': 3211,
#  'film': 1710,
#  'fun': 1827,
#  'download': 1418,
#  'filmaster': 1711,
#  'checkin': 946,
#  'recommendations': 4353,
#  'want make': 5849,
#  'make sxsw': 3214,
#  'app link': 337,
#  'roll': 4453,
#  'tractor': 5576,
#  'trailer': 5589,
#  'ipads': 2665,
#  'bet': 665,
#  'entire': 1541,
#  'inventory': 2526,
#  'justsaying': 2839,
#  'hey mention': 2277,
#  'mention roll': 3466,
#  'roll tractor': 4454,
#  'tractor trailer': 5577,
#  'trailer ipads': 5590,
#  'ipads sxsw': 2673,
#  'sxsw bet': 5074,
#  'bet sell': 666,
#  'sell entire': 4590,
#  'entire inventory': 1542,
#  'inventory justsaying': 2527,
#  'shitty': 4658,
#  'battery': 622,
#  'charging': 926,
#  'iphone battery': 2685,
#  'battery sxsw': 625,
#  'sxsw im': 5142,
#  'having': 2214,
#  'sxswi sxsw': 5282,
#  'little': 3088,
#  'need': 3661,
#  'comment': 1048,
#  'playing': 4034,
#  'playing ipad': 4036,
#  'ipad mention': 2593,
#  'networkquot': 3682,
#  'error': 1551,
#  'message': 3521,
#  'things': 5453,
#  'sxsw things': 5235,
#  'partner': 3880,
#  'says': 4533,
#  'looking': 3125,
#  'better': 669,
#  'products': 4152,
#  'google great': 1979,
#  'great partner': 2100,
#  'says mention': 4537,
#  'mention looking': 3437,
#  'products sxsw': 4154,
#  'function': 1833,
#  'lot': 3144,
#  'flight': 1733,
#  'mention sure': 3484,
#  'enjoying': 1529,
#  'california': 850,
#  'valley': 5767,
#  'sunny': 5012,
#  'enjoying sxsw': 1532,
#  'sxsw california': 5079,
#  'devices': 1329,
#  'step': 4895,
#  'ahead': 214,
#  'mobile devices': 3567,
#  '15k': 25,
#  'good': 1935,
#  'small': 4730,
#  'mags': 3208,
#  'chris': 967,
#  'tomlinson': 5540,
#  'texas': 5407,
#  'ap': 318,
#  'ipad app': 2541,
#  'makes': 3215,
#  'sense': 4605,
#  'makes good': 3217,
#  'action link': 165,
#  'tweets': 5648,
#  'thanks': 5417,
#  'thanks apple': 5418,
#  'apple sxsw': 421,
#  'sets': 4632,
#  'ft': 1820,
#  'temporary': 5388,
#  '2s': 65,
#  'cool apple': 1121,
#  'apple sets': 413,
#  'temporary store': 5393,
#  'store sxsw': 4948,
#  'sxsw sell': 5212,
#  'sell ipad': 4591,
#  'ipad 2s': 2537,
#  'gotta': 2068,
#  'fanboy': 1642,
#  'gtgt': 2131,
#  'begins': 646,
#  'wins': 5961,
#  'gotta love': 2070,
#  'apple fanboy': 375,
#  'begins apple': 647,
#  'apple wins': 426,
#  'wins sxsw': 5967,
#  'hobo': 2300,
#  'shotgun': 4670,
#  'video': 5785,
#  'game': 1853,
#  'ipadiphone': 2662,
#  'users': 5734,
#  'yes': 6087,
#  'hobo shotgun': 2302,
#  'game coming': 1856,
#  'yes link': 6092,
#  'joke': 2783,
#  'bad': 586,
#  'picture': 3995,
#  'hit': 2295,
#  'dude': 1466,
#  'killing': 2879,
#  'just google': 2811,
#  'killing sxsw': 2881,
#  'whos': 5924,
#  '64gb': 109,
#  '3g': 83,
#  'ill': 2396,
#  'right': 4423,
#  'ipad 3g': 2538,
#  'tech': 5351,
#  'ubersocial': 5669,
#  'uberguide': 5667,
#  'mention new': 3447,
#  'new ubersocial': 3710,
#  'ubersocial iphone': 5670,
#  'iphone app': 2680,
#  'store includes': 4926,
#  'includes uberguide': 2453,
#  'uberguide sxsw': 5668,
#  'snap': 4758,
#  '80s': 128,
#  'hosted': 2334,
#  '80s party': 129,
#  'party hosted': 3891,
#  'hosted google': 2335,
#  'google sxsw': 2023,
#  'crazy': 1158,
#  'doodles sxsw': 1411,
#  'wouldnt': 6041,
#  'think': 5459,
#  'watching': 5867,
#  'event': 1556,
#  'twitter': 5653,
#  'quotits': 4274,
#  'affirmative': 198,
#  'women': 5989,
#  'product': 4146,
#  'team': 5344,
#  'literally': 3086,
#  'betterquot': 674,
#  'nptech': 3758,
#  'quotits affirmative': 4275,
#  'affirmative action': 199,
#  'action having': 164,
#  'having women': 2218,
#  'women product': 5990,
#  'product team': 4150,
#  'team google': 5346,
#  'google literally': 1997,
#  'literally product': 3087,
#  'product betterquot': 4148,
#  'betterquot sxsw': 676,
#  'sxsw nptech': 5180,
#  'rumours': 4480,
#  'sxsw austin': 5069,
#  'austin texas': 539,
#  'market': 3268,
#  'ready': 4327,
#  'rock': 4444,
#  'apple app': 367,
#  'store android': 4913,
#  'android market': 297,
#  'getting ready': 1897,
#  'ready rock': 4329,
#  'rock sxsw': 4446,
#  'read': 4320,
#  'professionals': 4157,
#  'wont': 6002,
#  'save': 4509,
#  'usguys': 5747,
#  'usguys sxsw': 5748,
#  'museum': 3635,
#  'presentation': 4110,
#  'art': 470,
#  'project': 4161,
#  'funny': 1837,
#  'presentation google': 4111,
#  'google art': 1959,
#  'art project': 472,
#  'cool sxsw': 1127,
#  'hooray': 2323,
#  'opening': 3812,
#  'apple opening': 396,
#  'opening popup': 3815,
#  'austin sxsw': 536,
#  'sxsw mention': 5167,
#  'takes': 5312,
#  'biggest': 692,
#  'day': 1213,
#  'ipad takes': 2632,
#  'takes sxsw': 5314,
#  'sxsw video': 5252,
#  'day sxsw': 1225,
#  '64gig': 111,
#  'wifi': 5932,
#  'white': 5919,
#  'did': 1332,
#  'manage': 3229,
#  'sxsw ipad': 5146,
#  'ipad store': 2628,
#  'store sold': 4947,
#  'sold 64gig': 4783,
#  '64gig wifi': 112,
#  'wifi white': 5938,
#  'mention did': 3366,
#  'crowley': 1178,
#  'image': 2423,
#  'people': 3927,
#  'taking': 5315,
#  'photos': 3974,
#  'air': 217,
#  'mention people': 3454,
#  'taking photos': 5317,
#  'world': 6029,
#  '3d': 80,
#  'xml': 6060,
#  'youve': 6112,
#  '3d xml': 82,
#  'socially': 4774,
#  'experience': 1596,
#  'googledoodles': 2042,
#  'experience sxsw': 1598,
#  'sxsw googledoodles': 5128,
#  'apps': 447,
#  'khoi': 2856,
#  'vinh': 5799,
#  'instead': 2499,
#  'focusing': 1747,
#  'reader': 4323,
#  'content': 1105,
#  'ways': 5877,
#  'khoi vinh': 2857,
#  'add': 179,
#  'happen': 2191,
#  'happen sxsw': 2193,
#  'atampt': 486,
#  'user': 5733,
#  'friends': 1812,
#  'verizon': 5778,
#  'networks': 3683,
#  'slow': 4725,
#  'atampt iphone': 488,
#  'verizon iphone': 5779,
#  'thank': 5415,
#  'picked': 3990,
#  'book': 733,
#  'killer': 2873,
#  'photoes': 3972,
#  'sxswchi': 5273,
#  'thank rt': 5416,
#  'mention just': 3426,
#  'just picked': 2822,
#  'picked mention': 3992,
#  'mention book': 3349,
#  'book killer': 736,
#  'killer photoes': 2876,
#  'photoes iphone': 3973,
#  'sxsw sxswchi': 5228,
#  'sxswchi link': 5274,
#  'link sxswi': 3068,
#  'mention im': 3416,
#  'im line': 2411,
#  'ipad apple': 2542,
#  'win': 5941,
#  'win free': 5943,
#  'free ipad': 1793,
#  'sxsw rt': 5206,
#  'follow': 1752,
#  'customers': 1193,
#  'forbes': 1761,
#  'rest': 4393,
#  'genius': 1883,
#  'customers sxsw': 1195,
#  'leading': 2950,
#  'pack': 3851,
#  'growing': 2122,
#  'sxswmobileapps': 5285,
#  'mention iphone': 3422,
#  'sxswmobileapps sxsw': 5286,
#  'works': 6027,
#  'seriously': 4612,
#  'smart': 4733,
#  'works google': 6028,
#  'video link': 5789,
#  'holler': 2308,
#  'gram': 2082,
#  'madebymany': 3199,
#  'holler gram': 2309,
#  'gram ipad': 2084,
#  'itunes app': 2751,
#  'app madebymany': 339,
#  'lbs': 2949,
#  'check': 932,
#  'disney': 1365,
#  'vs': 5815,
#  'apps iphone': 452,
#  'behaving': 648,
#  'crashes': 1154,
#  'yesterday': 6096,
#  'ridiculous': 4420,
#  'nice mention': 3730,
#  'app behaving': 323,
#  'behaving today': 649,
#  'today crashes': 5531,
#  'crashes yesterday': 1156,
#  'yesterday ridiculous': 6097,
#  'ridiculous sxsw': 4421,
#  'huge': 2369,
#  'really': 4339,
#  'just saw': 2825,
#  'ipad line': 2586,
#  'line popup': 3025,
#  'popup apple': 4074,
#  'store people': 4944,
#  'people really': 3938,
#  'really want': 4347,
#  'want sxsw': 5851,
#  'hands': 2186,
#  'review': 4414,
#  'tomorrow': 5541,
#  'guest': 2138,
#  'post': 4090,
#  'hes': 2271,
#  'awesome hands': 570,
#  'hands review': 2188,
#  'review ipad': 4415,
#  'coming tomorrow': 1045,
#  'tomorrow mention': 5543,
#  'mention guest': 3397,
#  'guest post': 2139,
#  'post mention': 4091,
#  'mention hes': 3406,
#  'hes sxsw': 2272,
#  'arent': 464,
#  'missed': 3556,
#  'parties': 3876,
#  'making': 3224,
#  'white ipad': 5921,
#  'know': 2892,
#  'tweet': 5640,
#  'id': 2386,
#  'pics': 3993,
#  'pop': 4060,
#  'mention know': 3428,
#  'id love': 2387,
#  'apple pop': 400,
#  'pop store': 4065,
#  'tweetquot': 5646,
#  'quotthink': 4299,
#  'speakquot': 4835,
#  'belinsky': 654,
#  '911tweets': 134,
#  'mention quotgoogle': 3460,
#  'quotgoogle tweetquot': 4260,
#  'tweetquot new': 5647,
#  'new quotthink': 3708,
#  'quotthink speakquot': 4300,
#  'speakquot mark': 4836,
#  'mark belinsky': 3267,
#  'belinsky 911tweets': 655,
#  '911tweets panel': 135,
#  'panel sxsw': 3863,
#  'schools': 4552,
#  'marketing': 3272,
#  'experts': 1601,
#  'apple schools': 410,
#  'schools marketing': 4553,
#  'marketing experts': 3273,
#  'experts link': 1602,
#  'apple marketing': 392,
#  'long': 3111,
#  'lines': 3027,
#  'temp': 5385,
#  'street': 4972,
#  'unpack': 5688,
#  'theirs': 5433,
#  'long lines': 3114,
#  'temp apple': 5386,
#  'does': 1378,
#  'reviews': 4416,
#  'seo': 4606,
#  'seo sxsw': 4609,
#  'apple open': 394,
#  'open temporary': 3807,
#  'custom': 1187,
#  'case': 877,
#  'grill': 2111,
#  'awesome rt': 576,
#  'mention come': 3358,
#  'come check': 1027,
#  'check mention': 939,
#  'mention free': 3377,
#  'custom iphone': 1188,
#  'iphone case': 2689,
#  'case mention': 881,
#  'mention grill': 3392,
#  'ceo': 907,
#  'gowalla': 2071,
#  'tells': 5384,
#  'born': 746,
#  'turned': 5634,
#  'sponsored': 4848,
#  'sxsw sponsored': 5219,
#  'maps': 3240,
#  'hotpot': 2342,
#  'driving': 1450,
#  'term': 5399,
#  'web3': 5886,
#  'saatchiny': 4486,
#  'future networks': 1842,
#  'networks just': 3684,
#  'just data': 2808,
#  'data thats': 1212,
#  'thats google': 5428,
#  'google win': 2036,
#  'win long': 5945,
#  'long term': 3116,
#  'term sxsw': 5400,
#  'sxsw web3': 5256,
#  'web3 saatchiny': 5887,
#  'potential': 4092,
#  'iphone awesome': 2684,
#  'awesome sxsw': 577,
#  'moving': 3621,
#  'fruit': 1818,
#  'imacs': 2421,
#  'worth': 6039,
#  'sxsw line': 5157,
#  'cnnmoney': 1015,
#  '2011': 38,
#  'computing': 1068,
#  'device': 1325,
#  'bigger': 689,
#  'pass': 3907,
#  'space': 4819,
#  'buzz': 836,
#  'wssxsw': 6058,
#  'cnnmoney sxsw': 1016,
#  'sxsw 2011': 5057,
#  '2011 computing': 39,
#  'computing device': 1069,
#  'device bigger': 1327,
#  'bigger ipad': 690,
#  'ipad pass': 2601,
#  'pass mobile': 3908,
#  'mobile space': 3575,
#  'space buzz': 4820,
#  'buzz link': 837,
#  'link wssxsw': 3075,
#  'didnt': 1335,
#  'means': 3306,
#  'communication': 1050,
#  'stopped': 4910,
#  'working': 6024,
#  'fail': 1631,
#  'friends sxsw': 1815,
#  'sxsw think': 5236,
#  'google launch': 1992,
#  'called circles': 854,
#  'circles link': 977,
#  'guide': 2140,
#  'limited': 3010,
#  'lp': 3169,
#  'travel': 5595,
#  'austin guide': 519,
#  'guide iphone': 2142,
#  'iphone free': 2698,
#  'free limited': 1795,
#  'limited time': 3011,
#  'time link': 5506,
#  'link lp': 3054,
#  'lp travel': 3171,
#  'weekend': 5900,
#  'release': 4372,
#  'sadly': 4488,
#  'sxsw weekend': 5258,
#  'ipad release': 2613,
#  'thing': 5446,
#  'japan': 2760,
#  'mention wow': 3512,
#  'wow apple': 6043,
#  'apple does': 371,
#  'does right': 1381,
#  'right thing': 4427,
#  'thing japan': 5451,
#  'japan read': 2763,
#  'read link': 4322,
#  'morning': 3610,
#  'start': 4874,
#  'holding': 2307,
#  'someones': 4797,
#  'buying': 829,
#  'present': 4109,
#  'jealous': 2768,
#  'sets temporary': 4633,
#  'ipad2 link': 2651,
#  'link im': 3047,
#  'jealous sxsw': 2769,
#  'ordered': 3831,
#  'excited': 1575,
#  'silly': 4696,
#  'whats': 5916,
#  'happening': 2195,
#  'excited sxsw': 1577,
#  'sxsw silly': 5216,
#  'dear': 1235,
#  'tell': 5378,
#  'soon': 4805,
#  'dear mention': 1236,
#  'mention tell': 3493,
#  'sxsw thanks': 5234,
#  'iphones': 2737,
#  'geolocation': 1888,
#  'releasing': 4379,
#  'batterykiller': 626,
#  'iphones geolocation': 2738,
#  'batterykiller sxsw': 627,
#  'company': 1056,
#  'logo': 3105,
#  'win ipad': 5944,
#  'ipad link': 2587,
#  'spent': 4845,
#  'staring': 4871,
#  'year': 6071,
#  'people spent': 3939,
#  'year sxsw': 6076,
#  'sxsw just': 5152,
#  'releases': 4378,
#  'sxsw does': 5104,
#  'today ipad': 5532,
#  'word': 6011,
#  'quotcirclesquot': 4249,
#  'trending': 5596,
#  'mention ready': 3462,
#  'ready word': 4332,
#  'word quotcirclesquot': 6013,
#  'quotcirclesquot trending': 4251,
#  'trending sxswi': 5598,
#  'circles social': 980,
#  'version': 5780,
#  'web': 5881,
#  'site': 4704,
#  'demo': 1272,
#  'meet': 3314,
#  'awesome new': 575,
#  'new version': 3711,
#  'version mention': 5783,
#  'iphone amp': 2678,
#  'amp new': 271,
#  'new web': 3713,
#  'web site': 5885,
#  'site coming': 4705,
#  'sxsw want': 5254,
#  'want demo': 5845,
#  'demo meet': 1274,
#  'meet mention': 3316,
#  'won': 5991,
#  'gift': 1900,
#  'meetup': 3319,
#  'brand': 764,
#  'focuses': 1745,
#  'purpose': 4191,
#  'object': 3764,
#  'survive': 5037,
#  'succeed': 4996,
#  'useful': 5727,
#  'nike': 3738,
#  'sneakers': 4760,
#  ...}

# %%
cvect.get_feature_names()
# Out:
# ['10',
#  '10 attendees',
#  '10 hot',
#  '10 link',
#  '100',
#  '101',
#  '106',
#  '10x',
#  '11',
#  '12',
#  '12 months',
#  '12b',
#  '12b miles',
#  '136',
#  '136 google',
#  '1413',
#  '14day',
#  '14day return',
#  '15',
#  '15 minute',
#  '15 minutes',
#  '150',
#  '150 million',
#  '1500',
#  '1500 macbook',
#  '15k',
#  '16gb',
#  '16gb wifi',
#  '1986',
#  '1986quot',
#  '1st',
#  '1st day',
#  '1st prize',
#  '1st time',
#  '20',
#  '20 concept',
#  '20 min',
#  '2010',
#  '2011',
#  '2011 computing',
#  '2011 google',
#  '2011 link',
#  '2011 mention',
#  '2011 novelty',
#  '2011 prizes',
#  '2011 weekend',
#  '21',
#  '22',
#  '22 tracks',
#  '24',
#  '24 hours',
#  '247',
#  '247 amp',
#  '247 stream',
#  '25',
#  '250k',
#  '250k new',
#  '2day',
#  '2nd',
#  '2nd place',
#  '2nd prize',
#  '2not',
#  '2not worry',
#  '2quot',
#  '2quot mention',
#  '2s',
#  '2s austin',
#  '2s sxsw',
#  '30',
#  '30 android',
#  '313',
#  '315',
#  '315 details',
#  '32',
#  '32gb',
#  '330',
#  '330pm',
#  '35',
#  '35 million',
#  '37',
#  '3d',
#  '3d buildings',
#  '3d xml',
#  '3g',
#  '3g 64gb',
#  '3g 64mb',
#  '3g ipad',
#  '3g iphone',
#  '3gs',
#  '40',
#  '40 google',
#  '40 use',
#  '40 users',
#  '43',
#  '43 just',
#  '4chan',
#  '4g',
#  '4g austin',
#  '4sq',
#  '4sq sxsw',
#  '4sq3',
#  '4sq3 looks',
#  '4square',
#  '4squarequot',
#  '4squarequot link',
#  '50',
#  '52',
#  '52 looks',
#  '5pm',
#  '64gb',
#  '64gb wifi',
#  '64gig',
#  '64gig wifi',
#  '64mb',
#  '64mb apple',
#  '65',
#  '654',
#  '654 link',
#  '6th',
#  '6th amp',
#  '6th congress',
#  '6th st',
#  '6th time',
#  '70',
#  '70 1st',
#  '70 digital',
#  '70 went',
#  '75',
#  '80s',
#  '80s party',
#  '80sthemed',
#  '80sthemed costume',
#  '89',
#  '89 startups',
#  '911tweets',
#  '911tweets panel',
#  '915',
#  '915 hard',
#  '930',
#  '96',
#  '96 apple',
#  '99',
#  '______',
#  '______ quot',
#  'aapl',
#  'aapl open',
#  'able',
#  'absolutely',
#  'abt',
#  'abt google',
#  'access',
#  'accessibility',
#  'accessible',
#  'accessory',
#  'accesssxsw',
#  'accordion',
#  'accordion toodamnlucky',
#  'account',
#  'aclu',
#  'aclu google',
#  'aclu party',
#  'acquired',
#  'acquired 89',
#  'action',
#  'action having',
#  'action link',
#  'action showcase',
#  'action sxsw',
#  'action theyre',
#  'actionquot',
#  'actionquot link',
#  'actions',
#  'actions world',
#  'actsofsharingcom',
#  'actsofsharingcom tonight',
#  'actual',
#  'actually',
#  'ad',
#  'ad hoc',
#  'add',
#  'added',
#  'added clean',
#  'added sxsw',
#  'addition',
#  'admired',
#  'admired intelligent',
#  'admit',
#  'admit apple',
#  'admits',
#  'admits google',
#  'adoption',
#  'adoption google',
#  'ads',
#  'advertising',
#  'advice',
#  'advice google',
#  'advisory',
#  'advisory board',
#  'affirmative',
#  'affirmative action',
#  'afternoon',
#  'afternoon sxsw',
#  'agchat',
#  'agencies',
#  'agencies push',
#  'agents',
#  'agileagency',
#  'agileagency sxsw',
#  'ago',
#  'agree',
#  'agree mention',
#  'agreed',
#  'agreed novelty',
#  'ah',
#  'ahead',
#  'ahhh',
#  'aint',
#  'air',
#  'air ipad',
#  'airline',
#  'airline mentioned',
#  'airport',
#  'airports',
#  'aka',
#  'aka band',
#  'akqas',
#  'akqas mention',
#  'alarm',
#  'alarm google',
#  'album',
#  'album sxsw',
#  'alex',
#  'alex backup',
#  'alive',
#  'alive loving',
#  'allhat3',
#  'allow',
#  'allowing',
#  'alternate',
#  'alternate routes',
#  'amazing',
#  'amazing apple',
#  'amazing people',
#  'amazing sxsw',
#  'amazing vector',
#  'amazing way',
#  'amazingly',
#  'amazingly easy',
#  'america',
#  'america launched',
#  'americaquot',
#  'americaquot flipboard',
#  'americaquot kara',
#  'americaquot says',
#  'amp',
#  'amp android',
#  'amp best',
#  'amp bing',
#  'amp check',
#  'amp congress',
#  'amp droid',
#  'amp enter',
#  'amp fast',
#  'amp foursquare',
#  'amp google',
#  'amp ipad',
#  'amp iphone',
#  'amp light',
#  'amp live',
#  'amp mention',
#  'amp mobile',
#  'amp new',
#  'amp physical',
#  'amp share',
#  'amp start',
#  'amp succeed',
#  'amp track',
#  'amp wifi',
#  'ampipad',
#  'ampipad launch',
#  'analytics',
#  'analytics track',
#  'andoid',
#  'andoid app',
#  'android',
#  'android 30',
#  'android app',
#  'android apps',
#  'android available',
#  'android choice',
#  'android dev',
#  'android fan',
#  'android iphone',
#  'android just',
#  'android leading',
#  'android link',
#  'android looking',
#  'android market',
#  'android marketplace',
#  'android party',
#  'android passes',
#  'android phone',
#  'android phones',
#  'android push',
#  'android rt',
#  'android sxsw',
#  'android tablet',
#  'android version',
#  'androidsxsw',
#  'androidsxsw sxsw',
#  'announce',
#  'announce details',
#  'announced',
#  'announcing',
#  'announcing great',
#  'anybody',
#  'anymore',
#  'anymore quotgoogle',
#  'ap',
#  'app',
#  'app amp',
#  'app android',
#  'app awesome',
#  'app behaving',
#  'app built',
#  'app comes',
#  'app download',
#  'app example',
#  'app featured',
#  'app free',
#  'app getting',
#  'app got',
#  'app ipad',
#  'app iphone',
#  'app just',
#  'app killing',
#  'app lets',
#  'app link',
#  'app live',
#  'app madebymany',
#  'app makes',
#  'app mention',
#  'app moonbot',
#  'app nice',
#  'app nicely',
#  'app overlay',
#  'app really',
#  'app rt',
#  'app share',
#  'app song',
#  'app store',
#  'app sxsw',
#  'app team',
#  'app thanks',
#  'app time',
#  'app turnbyturn',
#  'app updates',
#  'app way',
#  'app youll',
#  'app yr',
#  'apparently',
#  'apparently spazmatics',
#  'appears',
#  'appears trending',
#  'apple',
#  'apple ad',
#  'apple amp',
#  'apple app',
#  'apple begins',
#  'apple credit',
#  'apple didnt',
#  'apple does',
#  'apple drumroll',
#  'apple effective',
#  'apple employees',
#  'apple fanboy',
#  'apple fanboys',
#  'apple fans',
#  'apple far',
#  'apple gap',
#  'apple google',
#  'apple great',
#  'apple hawk',
#  'apple ipad',
#  'apple ipad2',
#  'apple ipod',
#  'apple joy',
#  'apple just',
#  'apple keeping',
#  'apple knows',
#  'apple like',
#  'apple link',
#  'apple marketing',
#  'apple mention',
#  'apple open',
#  'apple opened',
#  'apple opening',
#  'apple opens',
#  'apple plaid',
#  'apple played',
#  'apple pop',
#  'apple popup',
#  'apple popupstore',
#  'apple product',
#  'apple products',
#  'apple quarter',
#  'apple quotthe',
#  'apple really',
#  'apple releasing',
#  'apple saves',
#  'apple schools',
#  'apple sell',
#  'apple set',
#  'apple sets',
#  'apple setting',
#  'apple smart',
#  'apple smartphone',
#  'apple sneaky',
#  'apple store',
#  'apple stores',
#  'apple stuff',
#  'apple sxsw',
#  'apple tablet',
#  'apple temporary',
#  'apple tv',
#  'apple winning',
#  'apple wins',
#  'apple winssxsw',
#  'appleatxdt',
#  'applequot',
#  'applequotthe',
#  'applequotthe classiest',
#  'apples',
#  'apples continued',
#  'apples ipad',
#  'apples notes',
#  'apples opening',
#  'apples popup',
#  'apples store',
#  'apples temporary',
#  'appolicious',
#  'appolicious app',
#  'appreciate',
#  'appreciate design',
#  'approaches',
#  'approved',
#  'approved new',
#  'apps',
#  'apps connected',
#  'apps fades',
#  'apps grooving',
#  'apps ipad',
#  'apps iphone',
#  'apps new',
#  'apps speech',
#  'apps survive',
#  'apps sxsw',
#  'apps using',
#  'apps weve',
#  'apps wins',
#  'apps youre',
#  'appstore',
#  'aquent',
#  'aquent booth',
#  'arent',
#  'aron',
#  'aron pilhofer',
#  'aroundquot',
#  'aroundquot feature',
#  'arrived',
#  'art',
#  'art ice',
#  'art project',
#  'article',
#  'article quotroll',
#  'article sxsw',
#  'artist',
#  'artist link',
#  'artists',
#  'artists grab',
#  'artistsquot',
#  'ask',
#  'asked',
#  'asleep',
#  'ass',
#  'assistedquot',
#  'atampt',
#  'atampt bring',
#  'atampt iphone',
#  'atampt phone',
#  'atrix',
#  'att',
#  'attempt',
#  'attend',
#  'attend sxsw',
#  'attendees',
#  'attendees blame',
#  'attendees course',
#  'attendees ipad2',
#  'attendees mac',
#  'attending',
#  'attending sxsw',
#  'attention',
#  'attracted',
#  'atx',
#  'atx sxsw',
#  'audience',
#  'audio',
#  'augmented',
#  'augmented reality',
#  'aus',
#  'austin',
#  'austin apple',
#  'austin bbq',
#  'austin city',
#  'austin convention',
#  'austin details',
#  'austin eats',
#  'austin enjoy',
#  'austin guide',
#  'austin igottagetit',
#  'austin ipad',
#  'austin iphone',
#  'austin java',
#  'austin just',
#  'austin link',
#  'austin mention',
#  'austin nerds',
#  'austin people',
#  'austin pics',
#  'austin pop',
#  'austin sell',
#  'austin selling',
#  'austin store',
#  'austin support',
#  'austin swarms',
#  'austin sxsw',
#  'austin tacos',
#  'austin tests',
#  'austin texas',
#  'austin tx',
#  'austinbound',
#  'austinbound apple',
#  'austins',
#  'auto',
#  'autocorrect',
#  'autocorrect tried',
#  'autocorrects',
#  'available',
#  'available android',
#  'available iphone',
#  'available link',
#  'ave',
#  'average',
#  'averages',
#  'averages better',
#  'avoid',
#  'avoiding',
#  'aw',
#  'aw sxsw',
#  'awards',
#  'awards thanks',
#  'away',
#  'away apple',
#  'away ipad',
#  'awesome',
#  'awesome austin',
#  'awesome day',
#  'awesome dude',
#  'awesome easier',
#  'awesome hands',
#  'awesome ipad',
#  'awesome ipadiphone',
#  'awesome iphone',
#  'awesome link',
#  'awesome new',
#  'awesome rt',
#  'awesome sxsw',
#  'awesomely',
#  'awesomely rad',
#  'awesomeness',
#  'awesomeness apple',
#  'awkward',
#  'baby',
#  'backup',
#  'backup charger',
#  'bad',
#  'bad news',
#  'badge',
#  'badge gets',
#  'badges',
#  'bag',
#  'bajillions',
#  'bajillions ipad2s',
#  'ballroom',
#  'banality',
#  'band',
#  'band michael',
#  'band rock',
#  'bands',
#  'bands food',
#  'bank',
#  'bank america',
#  'bankinnovation',
#  'bankinnovation sxsw',
#  'banks',
#  'bar',
#  'bar charge',
#  'bar sxsw',
#  'barely',
#  'barry',
#  'barry diller',
#  'bars',
#  'barton',
#  'based',
#  'based amp',
#  'based quotcirclesquot',
#  'basis',
#  'basis design',
#  'bat',
#  'bat bar',
#  'bathroom',
#  'battery',
#  'battery dies',
#  'battery life',
#  'battery sxsw',
#  'batterykiller',
#  'batterykiller sxsw',
#  'bavcid',
#  'bavcid sxsw',
#  'bb',
#  'bbq',
#  'bbq iphone',
#  'bbq sxsw',
#  'bc',
#  'beans',
#  'beans platform',
#  'beard',
#  'beard ipad',
#  'beat',
#  'beat free',
#  'beautiful',
#  'beautiful day',
#  'beautiful elegant',
#  'bed',
#  'beer',
#  'begins',
#  'begins apple',
#  'behaving',
#  'behaving today',
#  'behavior',
#  'behavior understand',
#  'believe',
#  'believe god',
#  'belinsky',
#  'belinsky 911tweets',
#  'best',
#  'best andoid',
#  'best apps',
#  'best butt',
#  'best buys',
#  'best ipad',
#  'best mention',
#  'best sxsw',
#  'best thing',
#  'bet',
#  'bet sell',
#  'beta',
#  'beta testing',
#  'better',
#  'better buzzquot',
#  'better ipad',
#  'better serve',
#  'better sxsw',
#  'betterquot',
#  'betterquot protecting',
#  'betterquot sxsw',
#  'bettersearch',
#  'bettersearch bing',
#  'big',
#  'big apple',
#  'big chunky',
#  'big events',
#  'big line',
#  'big news',
#  'big place',
#  'big social',
#  'big sxsw',
#  'big twitter',
#  'bigger',
#  'bigger ipad',
#  'bigger iphone',
#  'biggest',
#  'billion',
#  'bing',
#  'bing bettersearch',
#  'bing shot',
#  'bing smackdown',
#  'bing sxsw',
#  'bings',
#  'bings search',
#  'biomimicry',
#  'biomimicry basis',
#  'birds',
#  'bit',
#  'bit book',
#  'bitlyg03mzb',
#  'bitlyi41h53',
#  'bitlyi41h53 mention',
#  'biz',
#  'bizzy',
#  'black',
#  'blackberry',
#  'blackberry big',
#  'blackberry sxsw',
#  'blackberry users',
#  'blame',
#  'blame microsoft',
#  'block',
#  'block sxsw',
#  'blocks',
#  'blog',
#  'blog post',
#  'blog quotbig',
#  'blogger',
#  'blogger update',
#  'blogs',
#  'bloody',
#  'bloody banality',
#  'blue',
#  'blue hair',
#  'board',
#  'board link',
#  'book',
#  'book fetishism',
#  'book ipad',
#  'book killer',
#  'book popup',
#  'booth',
#  'booth 1413',
#  'booth fun',
#  'booth sxsw',
#  'booyah',
#  'booyah rt',
#  'bored',
#  'bored keynote',
#  'born',
#  'bots',
#  'bots experiment',
#  'bought',
#  'bought ipad',
#  'bought ipads',
#  'bounced',
#  'bounced catch',
#  'bout',
#  'boxes',
#  'boxes electronics',
#  'boyfriend',
#  'boyfriend aw',
#  'boys',
#  'boys im',
#  'bracket',
#  'brain',
#  'brain search',
#  'brand',
#  'brand focuses',
#  'brand values',
#  'break',
#  'break old',
#  'breakdown',
#  'breakdown sxsw',
#  'breaking',
#  'breakout',
#  'brick',
#  'brick austin',
#  'brief',
#  'brief case',
#  'brilliance',
#  'brilliant',
#  'brilliant apple',
#  'brilliant sxsw',
#  'bring',
#  'bring ipad',
#  'bring trucks',
#  'bringing',
#  'brings',
#  'brought',
#  'browse',
#  'browse events',
#  'browser',
#  'browser iphone',
#  'browserwars',
#  'browserwars panel',
#  'browsing',
#  'btchin',
#  'btchin party',
#  'build',
#  'building',
#  'building netflix',
#  'building real',
#  'building sxsw',
#  'buildings',
#  'built',
#  'built html5',
#  'built sxsw',
#  'bunch',
#  'burn',
#  'burn sxsw',
#  'bus',
#  'business',
#  'business apple',
#  'business instead',
#  'busy',
#  'butt',
#  'butt sxsw',
#  'button',
#  'button heat',
#  'buttons',
#  'buttons hack',
#  'butts',
#  'butts sxsw',
#  'buy',
#  'buy facebook',
#  'buy ipad',
#  'buy new',
#  'buy rt',
#  'buy sxsw',
#  'buyers',
#  'buyers report',
#  'buying',
#  'buying ipad',
#  'buying ipad2',
#  'buying new',
#  'buys',
#  'buys 14day',
#  'buys ipad',
#  'buzz',
#  'buzz link',
#  'buzz sxsw',
#  'buzzing',
#  'buzzquot',
#  'buzzquot rt',
#  'cab',
#  'cabbies',
#  'cabbies tech',
#  'cake',
#  'cake like',
#  'calendar',
#  'calendar featuring',
#  'calendar ur',
#  'california',
#  'callback',
#  'callback design',
#  'called',
#  'called circles',
#  'called circlesquot',
#  'called zms',
#  'cam',
#  'cam default',
#  'camera',
#  'cameras',
#  'cameras rigeur',
#  'canada',
#  'canada 2nd',
#  'canadian',
#  'canadian social',
#  'cancel',
#  'canvas',
#  'canvas library',
#  'capture',
#  'capture device',
#  'car',
#  'car sighting',
#  'card',
#  'care',
#  'caring',
#  'caring business',
#  'case',
#  'case boyfriend',
#  'case catch',
#  'case ipad',
#  'case mention',
#  'case study',
#  'case sxsw',
#  'cases',
#  'cases check',
#  'cases rad',
#  'cases sxsw',
#  'cash',
#  'cashmore',
#  'cashmore ipad',
#  'cashmore think',
#  'catch',
#  'catch googles',
#  'catch sxsw',
#  'catching',
#  'cause',
#  'causing',
#  'cbatsxsw',
#  'cc',
#  'cc mention',
#  'celebrate',
#  'celebrate charity',
#  'celebrating',
#  'center',
#  'center mention',
#  'center today',
#  'ceo',
#  'cera',
#  'cera ready',
#  'chain',
#  'chance',
#  'chance win',
#  'change',
#  'change quotcoworkersquot',
#  'changed',
#  'changes',
#  'changes gowalla',
#  'channels',
#  'charge',
#  'charge bar',
#  'charge iphone',
#  'charged',
#  'charger',
#  'charger iphone',
#  'chargers',
#  'charging',
#  'charity',
#  'charity water',
#  'charm',
#  'charts',
#  'charts link',
#  'check',
#  'check blog',
#  'check free',
#  'check googles',
#  'check googletv',
#  'check latest',
#  'check link',
#  'check mention',
#  'check new',
#  'check podcast',
#  'check reacquainted',
#  'check rt',
#  'check sxsw',
#  'checked',
#  'checkin',
#  'checking',
#  'checking ipad',
#  'checkins',
#  'checkins feature',
#  'checkins sxsw',
#  'checkout',
#  'checkout line',
#  'cheeky',
#  'cheeky app',
#  'chevysmc',
#  'chief',
#  'chief talent',
#  'chilltab',
#  'chilltab tablet',
#  'cho',
#  'cho sxsw',
#  'choice',
#  'choice awards',
#  'choice control',
#  'choice sxsw',
#  'chris',
#  'christmas',
#  'christmas nerds',
#  'chunky',
#  'chunky elements',
#  'cigarettes',
#  'circle',
#  'circles',
#  'circles ______',
#  'circles coming',
#  'circles link',
#  'circles possibly',
#  'circles real',
#  'circles social',
#  'circles sxsw',
#  'circles today',
#  'circlesquot',
#  'circlesquot mention',
#  'city',
#  'city end',
#  'city guide',
#  'clarity',
#  'clarity trumps',
#  'clarks',
#  'classiest',
#  'classiest fascist',
#  'classy',
#  'classy successful',
#  'cle',
#  'clean',
#  'clean donates',
#  'clean title',
#  'clear',
#  ...]

# %%
#Size of Document Term Matrix
X_train.shape
# Out:
# (2661, 6132)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Select classifier logistic regression
# - use logistic regression for predicting sentiment of the given tweet
# - initialize classifier

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()

# %% [markdown]
# ### Fit the classifer
# - fit logistic regression classifier

# %%
logisticRegr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Select classifier naive bayes
# - use naive bayes for predicting sentiment of the given tweet
# - initialize classifier
# - use MultinomialNB

# %%
from sklearn.naive_bayes import GaussianNB
naiBay = GaussianNB()

# %% [markdown]
# ### Fit the classifer
# - fit naive bayes classifier

# %%
naiBay.fit(X_train.toarray(), y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Make predictions on logistic regression
# - use your trained logistic regression model to make predictions on X_test

# %%
predictions = logisticRegr.predict(X_test)

# %% [markdown]
# ### Make predictions on naive bayes
# - use your trained naive bayes model to make predictions on X_test
# - use a different variable name to store predictions so that they are kept separately

# %%
predictionsNB = naiBay.predict(X_test.toarray())

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Calculate accuracy of logistic regression
# - check accuracy of logistic regression classifer
# - use sklearn.metrics.accuracy_score

# %%
score = logisticRegr.score(X_test, y_test)
print(score)
# Out:
# 0.8680947012401353

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_true=y_test, y_pred=predictions)
print('Acc: {:.4f}'.format(acc))
# Out:
# Acc: 0.8681

# %% [markdown]
# ### Calculate accuracy of naive bayes
# - check accuracy of naive bayes classifer
# - use sklearn.metrics.accuracy_score

# %%
acc = accuracy_score(y_true=y_test, y_pred=predictionsNB)
print('Acc: {:.4f}'.format(acc))
# Out:
# Acc: 0.8253

# %%
print('Logistic Regression gave better result than Naive Bayes')
# Out:
# Logistic Regression gave better result than Naive Bayes
